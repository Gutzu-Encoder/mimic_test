# %%
import json
import re
import time
import os
import pandas as pd
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
API_KEY = os.getenv("GLM_API_KEY")

INPUT_FILE   = r"C:\Users\USER\Downloads\medgemma_results_with_pd.csv"
MIMIC_FIXED  = r"C:\Users\USER\Downloads\augmented_data_mimic_fixed.csv"
OUTPUT_0SHOT = r"C:\Users\USER\Downloads\medgemma_glmjudge_0shot.csv"
OUTPUT_1SHOT = r"C:\Users\USER\Downloads\medgemma_glmjudge_1shot.csv"
MODEL = "glm-5.1"

client = OpenAI(
    api_key=API_KEY,
    base_url="https://open.bigmodel.cn/api/paas/v4/"
)

SYSTEM_PROMPT = """You are a clinical diagnostic auditor.
Evaluate the accuracy of the Model's extracted diagnosis against the Ground Truth.
Score D1 DIAGNOSIS ACCURACY (0-3).

3: Correct match (exact or clinically equivalent synonym).
2: Correct organ system/category, but wrong specificity.
1: Correct diagnosis appears only in differential/minor mention.
0: Incorrect or missing entirely.

Return ONLY JSON:
{
  "d1_accuracy": <0-3>,
  "model_dx": "<extracted model diagnosis>",
  "reasoning": "<one sentence explanation>"
}"""

def judge_accuracy(row):
    prompt = f"Model Diagnosis: {row['predicted_pd']}\nGround Truth: {row['LONG_TITLE']}"
    try:
        response = client.chat.completions.create(
            model=MODEL,
            messages=[
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user",   "content": prompt}
            ],
            max_tokens=3072,
            temperature=0.0
        )
        content = response.choices[0].message.content
        if not content or not content.strip():
            raise ValueError("Empty response from API")
        clean_content = re.sub(r"```json|```", "", content).strip()
        return json.loads(clean_content)
    except Exception as e:
        return {
            "d1_accuracy": -1,
            "model_dx": "",
            "reasoning": str(e)
        }

# %%
df = pd.read_csv(INPUT_FILE)

# Replace wrong ground truths — neweraugmented_mimic.csv had incorrect ICD codes for most HADMs
mimic_fixed = (
    pd.read_csv(MIMIC_FIXED)[['HADM_ID', 'ground_truth', 'SHORT_TITLE', 'LONG_TITLE']]
    .drop_duplicates('HADM_ID')
)
df = df.drop(columns=[c for c in ['ground_truth', 'SHORT_TITLE', 'LONG_TITLE'] if c in df.columns])
df = df.merge(mimic_fixed, on='HADM_ID', how='left')

print(f"Loaded {len(df)} rows | ground truth source: augmented_data_mimic_fixed.csv")
print(df[['HADM_ID', 'LONG_TITLE']].drop_duplicates('HADM_ID').to_string(index=False))

df_baseline = (
    df[df['condition'].isin(['0-shot', '1-shot'])]
    .drop_duplicates(subset=['HADM_ID', 'condition'], keep='first')
    .copy()
)

n_0shot = (df_baseline['condition'] == '0-shot').sum()
n_1shot = (df_baseline['condition'] == '1-shot').sum()
print(f"\nProcessing {len(df_baseline)} baseline rows: {n_0shot} x 0-shot, {n_1shot} x 1-shot")

results = []
for i, (_, row) in enumerate(df_baseline.iterrows()):
    condition = row['condition']
    print(f"[{i+1}/{len(df_baseline)}] [{condition}] HADM {row['HADM_ID']}...")

    evaluation = judge_accuracy(row)
    print(evaluation)

    combined = {**row.to_dict(), **evaluation}
    results.append(combined)

    time.sleep(0.5)

results_df = pd.DataFrame(results)

df_0shot = results_df[results_df['condition'] == '0-shot']
df_1shot = results_df[results_df['condition'] == '1-shot']

df_0shot.to_csv(OUTPUT_0SHOT, index=False)
df_1shot.to_csv(OUTPUT_1SHOT, index=False)

print(f"\n--- Results ---")
print(f"0-shot  ({len(df_0shot)} rows) → {OUTPUT_0SHOT}  |  avg d1: {df_0shot['d1_accuracy'].mean():.2f}")
print(f"1-shot  ({len(df_1shot)} rows) → {OUTPUT_1SHOT}  |  avg d1: {df_1shot['d1_accuracy'].mean():.2f}")
# Out:
# Loaded 50 rows | ground truth source: augmented_data_mimic_fixed.csv
#  HADM_ID                                                       LONG_TITLE
#   197345   Secondary malignant neoplasm of retroperitoneum and peritoneum
#   176830                Hemorrhage of gastrointestinal tract, unspecified
#   146302                                         Other diseases of spleen
#   101908          Other pulmonary insufficiency, not elsewhere classified
#   181521                            Congestive heart failure, unspecified
#   194302                     Other colostomy and enterostomy complication
#   130788 Other diseases of trachea and bronchus, not elsewhere classified
#   186753               Coronary atherosclerosis of native coronary artery
#   166328                                    Other postoperative infection
#   128089                                           Unspecified septicemia
#
# Processing 20 baseline rows: 10 x 0-shot, 10 x 1-shot
# [1/20] [0-shot] HADM 197345...
# {'d1_accuracy': 2, 'model_dx': 'Metastatic Breast Cancer', 'reasoning': 'The model identifies the primary malignancy and its metastatic nature, which falls under the same general category of metastatic cancer, but lacks the specificity of the secondary site (retroperitoneum and peritoneum) indicated in the ground truth.'}
# [2/20] [1-shot] HADM 197345...
# {'d1_accuracy': 3, 'model_dx': 'metastatic breast cancer with peritoneal carcinomatosis', 'reasoning': 'Peritoneal carcinomatosis is a clinically equivalent synonym for secondary malignant neoplasm of the peritoneum, which maps to the same clinical classification as the ground truth.'}
# [3/20] [0-shot] HADM 176830...
# {'d1_accuracy': 3, 'model_dx': 'Gastrointestinal bleed', 'reasoning': 'Gastrointestinal bleed is a clinically equivalent synonym for hemorrhage of gastrointestinal tract, meeting the criteria for a correct match despite the unspecified nature in the ground truth.'}
# [4/20] [1-shot] HADM 176830...
# {'d1_accuracy': 3, 'model_dx': 'Recurrent Gastrointestinal Bleed', 'reasoning': "Gastrointestinal bleed is a clinically equivalent synonym for hemorrhage of gastrointestinal tract, and the addition of 'recurrent' is a temporal modifier that does not alter the core diagnosis."}
# [5/20] [0-shot] HADM 146302...
# {'d1_accuracy': 2, 'model_dx': 'Large Subcapsular Splenic Hematoma', 'reasoning': 'The model correctly identified the organ system and general pathological category (spleen disease), but provided a highly specific diagnosis rather than the broad category listed in the ground truth.'}
# [6/20] [1-shot] HADM 146302...
# {'d1_accuracy': 2, 'model_dx': 'Splenic Hematoma', 'reasoning': 'The model identified the correct organ system (spleen) but provided a specific diagnosis rather than the broad category listed in the ground truth.'}
# [7/20] [0-shot] HADM 101908...
# {'d1_accuracy': 0, 'model_dx': 'Renal cell carcinoma', 'reasoning': 'The model diagnosis of renal cell carcinoma is entirely incorrect and belongs to a different organ system compared to the ground truth of pulmonary insufficiency.'}
# [8/20] [1-shot] HADM 101908...
# {'d1_accuracy': 2, 'model_dx': 'Post-obstructive pneumonia', 'reasoning': 'Both conditions fall under the correct organ system (pulmonary/respiratory), but post-obstructive pneumonia and pulmonary insufficiency are distinct clinical entities rather than equivalent diagnoses.'}
# [9/20] [0-shot] HADM 181521...
# {'d1_accuracy': 2, 'model_dx': 'Acute Coronary Syndrome (ACS)', 'reasoning': 'Both conditions belong to the cardiovascular organ system, but Acute Coronary Syndrome and Congestive Heart Failure are distinct clinical diagnoses rather than equivalent or differing only in specificity.'}
# [10/20] [1-shot] HADM 181521...
# {'d1_accuracy': 2, 'model_dx': 'Acute Coronary Syndrome (ACS)', 'reasoning': 'Both conditions belong to the cardiovascular organ system/category, but Acute Coronary Syndrome and Congestive Heart Failure are distinct diagnoses with different pathophysiologies rather than variations in specificity of the same condition.'}
# [11/20] [0-shot] HADM 194302...
# {'d1_accuracy': 2, 'model_dx': 'Small Bowel Obstruction', 'reasoning': 'Both conditions involve the gastrointestinal/intestinal system, but small bowel obstruction is a specific pathological diagnosis rather than the general post-procedural complication category specified in the ground truth.'}
# [12/20] [1-shot] HADM 194302...
# {'d1_accuracy': 2, 'model_dx': 'Small Bowel Obstruction', 'reasoning': 'Both conditions involve the gastrointestinal system, but small bowel obstruction is a specific diagnosis whereas the ground truth refers to a broader category of post-procedural complications, indicating wrong specificity.'}
# [13/20] [0-shot] HADM 130788...
# {'d1_accuracy': 2, 'model_dx': 'Subglottic Stenosis', 'reasoning': 'The model identified a specific disease of the trachea, which matches the correct organ system and category of the ground truth, but lacks the exact specificity of the broad ICD classification.'}
# [14/20] [1-shot] HADM 130788...
# {'d1_accuracy': 2, 'model_dx': 'Tracheomalacia', 'reasoning': 'The model identified a specific disease of the trachea, which matches the correct organ system/category of the ground truth, but the ground truth is a broad, non-specific residual category rather than the specific condition.'}
# [15/20] [0-shot] HADM 186753...
# {'d1_accuracy': 2, 'model_dx': 'Acute Coronary Syndrome (ACS)', 'reasoning': 'Both conditions involve the coronary artery system, but ACS is an acute syndrome while coronary atherosclerosis is a chronic anatomical pathology, representing wrong specificity.'}
# [16/20] [1-shot] HADM 186753...
# {'d1_accuracy': 2, 'model_dx': 'Acute Coronary Syndrome (ACS)', 'reasoning': 'Both diagnoses involve the coronary arteries and cardiovascular system, but ACS is an acute clinical syndrome while coronary atherosclerosis is a chronic anatomical pathology, representing wrong specificity.'}
# [17/20] [0-shot] HADM 166328...
# {'d1_accuracy': 0, 'model_dx': 'Malnutrition with Enteral Nutrition', 'reasoning': 'The model diagnosis of malnutrition is entirely different from the ground truth of postoperative infection, with no overlap in clinical category or organ system.'}
# [18/20] [1-shot] HADM 166328...
# {'d1_accuracy': 0, 'model_dx': 'Malnutrition (protein-energy, unspecified)', 'reasoning': 'The model diagnosis of malnutrition is entirely incorrect and belongs to a different clinical category than the ground truth of postoperative infection.'}
# [19/20] [0-shot] HADM 128089...
# {'d1_accuracy': 2, 'model_dx': 'Urosepsis', 'reasoning': 'Urosepsis matches the correct general category of septicemia but provides a specific urinary source, differing in specificity from the unspecified ground truth.'}
# [20/20] [1-shot] HADM 128089...
# {'d1_accuracy': 3, 'model_dx': 'Urosepsis', 'reasoning': 'Urosepsis is a clinically equivalent and more specific form of septicemia, matching the core diagnosis of the ground truth.'}
#
# --- Results ---
# 0-shot  (10 rows) → C:\Users\USER\Downloads\medgemma_glmjudge_0shot.csv  |  avg d1: 1.70
# 1-shot  (10 rows) → C:\Users\USER\Downloads\medgemma_glmjudge_1shot.csv  |  avg d1: 2.10
