# %%
import json
import re
import time
import os
import pandas as pd
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
API_KEY = os.getenv("GLM_API_KEY")

INPUT_FILE   = r"C:\Users\USER\Downloads\qwen3_6_results_with_pd.csv"
OUTPUT_0SHOT = r"C:\Users\USER\Downloads\qwen_glmjudge_0shot.csv"
OUTPUT_1SHOT = r"C:\Users\USER\Downloads\qwen_glmjudge_1shot.csv"
MODEL = "glm-5.1"

client = OpenAI(
    api_key=API_KEY,
    base_url="https://open.bigmodel.cn/api/paas/v4/"
)

SYSTEM_PROMPT = """You are a clinical diagnostic auditor.
Evaluate the accuracy of the Model's extracted diagnosis against the Ground Truth.
Score D1 DIAGNOSIS ACCURACY (0-3).

3: Correct match (exact or clinically equivalent synonym).
2: Correct organ system/category, but wrong specificity.
1: Correct diagnosis appears only in differential/minor mention.
0: Incorrect or missing entirely.

Return ONLY JSON:
{
  "d1_accuracy": <0-3>,
  "model_dx": "<extracted model diagnosis>",
  "reasoning": "<one sentence explanation>"
}"""

def judge_accuracy(row):
    prompt = f"Model Diagnosis: {row['predicted_pd']}\nGround Truth: {row['LONG_TITLE']}"
    try:
        response = client.chat.completions.create(
            model=MODEL,
            messages=[
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user", "content": prompt}
            ],
            max_tokens=3072,
            temperature=0.0
        )
        content = response.choices[0].message.content
        if not content or not content.strip():
            raise ValueError("Empty response from API")
        clean_content = re.sub(r"```json|```", "", content).strip()
        return json.loads(clean_content)
    except Exception as e:
        return {
            "d1_accuracy": -1,
            "model_dx": "",
            "reasoning": str(e)
        }

# %%
MIMIC_FIXED = r"C:\Users\USER\Downloads\augmented_data_mimic_fixed.csv"

df = pd.read_csv(INPUT_FILE)

# Replace wrong ground truths — qwen3_6_results_with_pd.csv inherited wrong ICD codes from neweraugmented_mimic.csv
mimic_fixed = (
    pd.read_csv(MIMIC_FIXED)[['HADM_ID', 'ground_truth', 'SHORT_TITLE', 'LONG_TITLE']]
    .drop_duplicates('HADM_ID')
)
df = df.drop(columns=[c for c in ['ground_truth', 'SHORT_TITLE', 'LONG_TITLE'] if c in df.columns])
df = df.merge(mimic_fixed, on='HADM_ID', how='left')

print(f"Loaded {len(df)} rows | ground truth source: augmented_data_mimic_fixed.csv")
print(df[['HADM_ID', 'LONG_TITLE']].drop_duplicates('HADM_ID').to_string(index=False))

df_baseline = (
    df[df['condition'].isin(['0-shot', '1-shot'])]
    .drop_duplicates(subset=['HADM_ID', 'condition'], keep='first')
    .copy()
)

n_0shot = (df_baseline['condition'] == '0-shot').sum()
n_1shot = (df_baseline['condition'] == '1-shot').sum()
print(f"\nProcessing {len(df_baseline)} baseline rows: {n_0shot} x 0-shot, {n_1shot} x 1-shot")

results = []
for i, (_, row) in enumerate(df_baseline.iterrows()):
    condition = row['condition']
    print(f"[{i+1}/{len(df_baseline)}] [{condition}] HADM {row['HADM_ID']}...")

    evaluation = judge_accuracy(row)
    print(evaluation)

    combined = {**row.to_dict(), **evaluation}
    results.append(combined)

    time.sleep(0.5)

results_df = pd.DataFrame(results)

df_0shot = results_df[results_df['condition'] == '0-shot']
df_1shot = results_df[results_df['condition'] == '1-shot']

df_0shot.to_csv(OUTPUT_0SHOT, index=False)
df_1shot.to_csv(OUTPUT_1SHOT, index=False)

print(f"\n--- Results ---")
print(f"0-shot  ({len(df_0shot)} rows) → {OUTPUT_0SHOT}  |  avg d1: {df_0shot['d1_accuracy'].mean():.2f}")
print(f"1-shot  ({len(df_1shot)} rows) → {OUTPUT_1SHOT}  |  avg d1: {df_1shot['d1_accuracy'].mean():.2f}")
# Out:
# Loaded 50 rows | ground truth source: augmented_data_mimic_fixed.csv
#  HADM_ID                                                       LONG_TITLE
#   101908          Other pulmonary insufficiency, not elsewhere classified
#   128089                                           Unspecified septicemia
#   130788 Other diseases of trachea and bronchus, not elsewhere classified
#   146302                                         Other diseases of spleen
#   166328                                    Other postoperative infection
#   176830                Hemorrhage of gastrointestinal tract, unspecified
#   181521                            Congestive heart failure, unspecified
#   186753               Coronary atherosclerosis of native coronary artery
#   194302                     Other colostomy and enterostomy complication
#   197345   Secondary malignant neoplasm of retroperitoneum and peritoneum
#
# Processing 20 baseline rows: 10 x 0-shot, 10 x 1-shot
# [1/20] [0-shot] HADM 101908...
# {'d1_accuracy': 1, 'model_dx': 'Metastatic Renal Cell Carcinoma (with post-obstructive pneumonia/respiratory failure)', 'reasoning': "The ground truth diagnosis of pulmonary insufficiency is only mentioned as a minor/secondary complication (respiratory failure) in the model's extracted diagnosis, while the primary diagnosis of metastatic renal cell carcinoma is incorrect."}
# [2/20] [1-shot] HADM 101908...
# {'d1_accuracy': 0, 'model_dx': 'Metastatic Renal Cell Carcinoma', 'reasoning': "The model's diagnosis of metastatic renal cell carcinoma is entirely incorrect and shares no overlap with the ground truth of pulmonary insufficiency."}
# [3/20] [0-shot] HADM 128089...
# {'d1_accuracy': 2, 'model_dx': 'Urosepsis (Sepsis secondary to Urinary Tract Infection)', 'reasoning': 'The model correctly identifies the general category of septicemia/sepsis but provides a more specific diagnosis (specifying the urinary tract origin) than the unspecified ground truth, resulting in a mismatch in specificity.'}
# [4/20] [1-shot] HADM 128089...
# {'d1_accuracy': 0, 'model_dx': 'ERROR: Unterminated string starting at: line 1 column 25 (char 24)', 'reasoning': 'The model output is a parsing error message rather than a valid diagnosis, so the diagnosis is missing entirely.'}
# [5/20] [0-shot] HADM 130788...
# {'d1_accuracy': 3, 'model_dx': 'Severe Tracheobronchomalacia (ICD-10-CM: J98.2)', 'reasoning': "The model's specific diagnosis of severe tracheobronchomalacia maps exactly to the ground truth's ICD-10-CM code J98.2, making it a clinically equivalent and correct match."}
# [6/20] [1-shot] HADM 130788...
# {'d1_accuracy': 2, 'model_dx': 'Severe Tracheobronchomalacia (Dynamic Airway Collapse)', 'reasoning': "The model's diagnosis is a specific condition that falls under the general category of the ground truth (diseases of trachea and bronchus), but they do not match exactly as the ground truth is a broad, non-specific classification."}
# [7/20] [0-shot] HADM 146302...
# {'d1_accuracy': 2, 'model_dx': 'splenic hematoma', 'reasoning': 'The model identified a specific condition within the correct organ system (spleen), but the ground truth is a broader, less specific category.'}
# [8/20] [1-shot] HADM 146302...
# {'d1_accuracy': 2, 'model_dx': 'Splenic Hematoma with Intraperitoneal Hemorrhage', 'reasoning': "The model's diagnosis is a specific condition that falls under the broad category of the ground truth, matching the organ system but differing in specificity."}
# [9/20] [0-shot] HADM 166328...
# {'d1_accuracy': 2, 'model_dx': 'Complicated intra-abdominal infection', 'reasoning': 'Both diagnoses fall under the broad category of infection, but they differ in specificity as the model specifies intra-abdominal while the ground truth specifies postoperative.'}
# [10/20] [1-shot] HADM 166328...
# {'d1_accuracy': 0, 'model_dx': 'Malnutrition', 'reasoning': 'Malnutrition and other postoperative infection are completely distinct conditions with no overlap in organ system or clinical category.'}
# [11/20] [0-shot] HADM 176830...
# {'d1_accuracy': 3, 'model_dx': 'Gastrointestinal Bleeding (Recurrent Lower GI Hemorrhage)', 'reasoning': "Gastrointestinal bleeding is a clinically equivalent synonym for hemorrhage of the gastrointestinal tract, and the model's added specificity of 'lower' does not contradict the unspecified ground truth."}
# [12/20] [1-shot] HADM 176830...
# {'d1_accuracy': 2, 'model_dx': 'Lower gastrointestinal hemorrhage (Gastrointestinal bleed)', 'reasoning': 'The model correctly identifies the gastrointestinal bleed but adds incorrect specificity (lower) compared to the unspecified ground truth.'}
# [13/20] [0-shot] HADM 181521...
# {'d1_accuracy': 2, 'model_dx': 'Acute Myocardial Infarction (STEMI) / Coronary Artery Disease', 'reasoning': 'Both conditions fall under the correct cardiovascular organ system/category, but they represent distinct disease processes (ischemic event/artery disease vs. pump failure) rather than just a difference in specificity.'}
# [14/20] [1-shot] HADM 181521...
# {'d1_accuracy': 2, 'model_dx': 'Acute ST-segment elevation myocardial infarction (STEMI)', 'reasoning': 'Both conditions fall under the cardiovascular system category, but STEMI and congestive heart failure are distinct clinical diagnoses rather than variations in specificity of the same condition.'}
# [15/20] [0-shot] HADM 186753...
# {'d1_accuracy': 2, 'model_dx': 'Unstable Angina (Acute Coronary Syndrome)', 'reasoning': 'Both conditions belong to the same cardiovascular organ system and are related, but unstable angina is an acute clinical syndrome whereas coronary atherosclerosis is the underlying chronic pathological condition, representing a difference in specificity.'}
# [16/20] [1-shot] HADM 186753...
# {'d1_accuracy': 0, 'model_dx': 'ERROR: Expecting value: line 1 column 1 (char 0)', 'reasoning': 'The model failed to extract a diagnosis and returned an error message, resulting in a completely missing diagnosis.'}
# [17/20] [0-shot] HADM 194302...
# {'d1_accuracy': 2, 'model_dx': 'Small Bowel Obstruction (SBO) secondary to adhesions and parastomal hernia', 'reasoning': 'The model provides a specific diagnosis (SBO secondary to parastomal hernia) that falls under the broader ground truth category of colostomy/enterostomy complications, representing a difference in specificity.'}
# [18/20] [1-shot] HADM 194302...
# {'d1_accuracy': 2, 'model_dx': 'Small Bowel Obstruction (secondary to adhesions and parastomal hernia)', 'reasoning': 'The model identifies a specific condition (SBO secondary to parastomal hernia) that falls under the broader category of the ground truth (colostomy/enterostomy complication), representing the correct organ system and clinical category but with differing specificity.'}
# [19/20] [0-shot] HADM 197345...
# {'d1_accuracy': 2, 'model_dx': 'Metastatic Breast Cancer', 'reasoning': 'Both indicate metastatic malignancy sharing the same general category, but they differ in specificity as the model specifies the primary site (breast) while the ground truth specifies the metastatic site (retroperitoneum and peritoneum).'}
# [20/20] [1-shot] HADM 197345...
# {'d1_accuracy': 2, 'model_dx': 'Metastatic Breast Cancer (Refractory, with widespread metastases)', 'reasoning': 'The model identifies the correct general category of metastatic malignancy but specifies the primary site (breast) rather than the specific secondary metastatic sites (retroperitoneum and peritoneum) detailed in the ground truth.'}
#
# --- Results ---
# 0-shot  (10 rows) → C:\Users\USER\Downloads\qwen_glmjudge_0shot.csv  |  avg d1: 2.10
# 1-shot  (10 rows) → C:\Users\USER\Downloads\qwen_glmjudge_1shot.csv  |  avg d1: 1.20
