# %%
import json
import re
import time
import os
import pandas as pd
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()

INPUT_FILE  = r"C:\Users\USER\Downloads\der_llama_dsk_8b_results (1).csv"
OUTPUT_FILE = r"C:\Users\USER\Downloads\llama_dsk_8b_results_with_pd.csv"

def strip_thinking(text: str) -> str:
    if '</think>' in text:
        return text.split('</think>', 1)[1].strip()
    return text.strip()

# B: **Principal Diagnosis:** **text**  (label bold, value separately bold)
_PB = re.compile(
    r'\*\*(?:Final\s+|Most Supported\s+)?Principal Diagnosis:\*\*\s*\*\*([^*\n]{3,300})\*\*',
    re.IGNORECASE,
)

# A: **Principal Diagnosis: text**  (colon + text inside same bold span)
_PA = re.compile(
    r'\*\*(?:Final\s+|Most Supported\s+)?Principal Diagnosis:\s+([^*\n]{3,300})\*\*',
    re.IGNORECASE,
)

# C: **Principal Diagnosis:** plain text  (label bold, value plain — stops at * or newline)
_PC = re.compile(
    r'\*\*(?:Final\s+|Most Supported\s+)?Principal Diagnosis:\*\*\s+(?!\*\*)([^\n*]{3,300})',
    re.IGNORECASE,
)

# D: The [most supported] principal diagnosis [for this patient] is [the] **text**
_PD = re.compile(
    r'(?:The\s+)?(?:most\s+supported\s+)?principal diagnosis(?:\s+for\s+this\s+patient)?[:\s]+is[:\s]+(?:the\s+)?\*\*([^*\n]{3,200})\*\*',
    re.IGNORECASE,
)

# E: **text** **Rationale/Reasoning/Step-by-Step:**  (bold value then section header)
_PE = re.compile(
    r'(?:^|\n)\s*\*\*([^*\n]{3,200})\*\*\s+\*\*(?:Rationale|Reasoning|Step-by-Step)',
    re.IGNORECASE,
)

PATTERNS = [_PB, _PA, _PC, _PD, _PE]

def extract_with_regex(text: str):
    clean = strip_thinking(text)
    for pat in PATTERNS:
        matches = pat.findall(clean)
        if matches:
            return matches[0].strip().rstrip('*').strip()
    return None

# Self-test
_tests = [
    ('**Principal Diagnosis: Metastatic Breast Cancer**\n**Reasoning:** ...', 'Metastatic Breast Cancer'),
    ('**Principal Diagnosis: Coronary Artery Disease**\n**Step-by-Step Explanation:**', 'Coronary Artery Disease'),
    ('**Principal Diagnosis:** **Large Subcapsular Splenic Hematoma**  **Rationale:**', 'Large Subcapsular Splenic Hematoma'),
    ('**Principal Diagnosis:**   **Acute Coronary Syndrome Secondary to Chronic CAD**  **Rationale:**', 'Acute Coronary Syndrome Secondary to Chronic CAD'),
    ('**Principal Diagnosis:** Renal Cell Carcinoma  **Rationale:**', 'Renal Cell Carcinoma'),
    ('**Principal Diagnosis:** Small Bowel Obstruction Secondary to Parastomal Hernia  **Rationale:**', 'Small Bowel Obstruction Secondary to Parastomal Hernia'),
    ('The principal diagnosis for this patient is **Gastrointestinal Bleed**.', 'Gastrointestinal Bleed'),
    ('The principal diagnosis for this patient is the **splenic hematoma and ascites**', 'splenic hematoma and ascites'),
    ('The most supported principal diagnosis for this patient is **Renal Cell Carcinoma**.', 'Renal Cell Carcinoma'),
    ('The most supported principal diagnosis for this patient is:  **Heart Failure, Unspecified, Acute or Chronic**', 'Heart Failure, Unspecified, Acute or Chronic'),
    ('<think>blah blah</think>\n**Principal Diagnosis: Urosepsis**\n**Reasoning:**', 'Urosepsis'),
]
print('Self-test:')
for text, expected in _tests:
    got = extract_with_regex(text)
    status = 'OK' if (got and expected.lower() in got.lower()) else f'FAIL (got: {got!r})'
    print(f'  {status} | expected: {expected!r}')
# Out:
# Self-test:
#   OK | expected: 'Metastatic Breast Cancer'
#   OK | expected: 'Coronary Artery Disease'
#   OK | expected: 'Large Subcapsular Splenic Hematoma'
#   OK | expected: 'Acute Coronary Syndrome Secondary to Chronic CAD'
#   OK | expected: 'Renal Cell Carcinoma'
#   OK | expected: 'Small Bowel Obstruction Secondary to Parastomal Hernia'
#   OK | expected: 'Gastrointestinal Bleed'
#   OK | expected: 'splenic hematoma and ascites'
#   OK | expected: 'Renal Cell Carcinoma'
#   OK | expected: 'Heart Failure, Unspecified, Acute or Chronic'
#   OK | expected: 'Urosepsis'

# %%
API_KEY = os.getenv('DEEPSEEK_API_KEY')
MODEL   = 'deepseek-v4-flash'

client = OpenAI(api_key=API_KEY, base_url='https://api.deepseek.com')

EXTRACT_SYSTEM = """You are a clinical NLP extraction assistant.
You will receive the FINAL portion of a model's clinical reasoning output.
Your only job: identify the model's stated principal diagnosis and return it as a short phrase.

Rules:
- Extract exactly what the model concludes, do not infer or add information.
- If the model explicitly names a diagnosis at the end, use that.
- If ambiguous between two candidates, pick the one stated last or most emphatically.
- Strip ICD codes, qualifiers like (with secondary ...), footnotes — keep only the core diagnosis name.
- If no clear principal diagnosis is stated, return UNCLEAR.

Return ONLY valid JSON (no markdown fences):
{"principal_diagnosis": "<short diagnosis phrase>"}"""


def extract_with_llm(tail: str) -> str:
    try:
        resp = client.chat.completions.create(
            model=MODEL,
            messages=[
                {'role': 'system', 'content': EXTRACT_SYSTEM},
                {'role': 'user',   'content': tail},
            ],
            max_tokens=128,
            temperature=0.0,
        )
        raw = resp.choices[0].message.content
        clean = re.sub(r'```json|```', '', raw).strip()
        return json.loads(clean)['principal_diagnosis']
    except Exception as e:
        return f'ERROR: {e}'

# %%
df = pd.read_csv(INPUT_FILE)
print(f'Loaded {len(df)} rows from {INPUT_FILE}')

predicted_pds = []
methods       = []

for i, row in df.iterrows():
    text = str(row['final_answer'])

    pd_value = extract_with_regex(text)
    if pd_value:
        method = 'regex'
    else:
        clean    = strip_thinking(text)
        tail     = clean[-1200:]
        pd_value = extract_with_llm(tail)
        method   = 'llm'
        time.sleep(0.3)

    print(f'[{i+1:>2}/{len(df)}] HADM={row["HADM_ID"]} cond={row["condition"]:<15} [{method}] {str(pd_value)[:90]}')
    predicted_pds.append(pd_value)
    methods.append(method)

df['predicted_pd'] = predicted_pds
df['pd_method']    = methods

df.to_csv(OUTPUT_FILE, index=False)

n_regex = methods.count('regex')
n_llm   = methods.count('llm')
n_err   = sum(1 for v in predicted_pds if str(v).startswith('ERROR'))
print(f'\nDone -> {OUTPUT_FILE}')
print(f'  regex extracted : {n_regex}/{len(df)}')
print(f'  llm  extracted  : {n_llm}/{len(df)}')
print(f'  errors          : {n_err}')
print()
print(df[['HADM_ID', 'condition', 'predicted_pd', 'pd_method']].to_string(index=False))
# Out:
# Loaded 50 rows from C:\Users\USER\Downloads\der_llama_dsk_8b_results (1).csv
# [ 1/50] HADM=197345 cond=0-shot          [regex] Metastatic Breast Cancer
# [ 2/50] HADM=197345 cond=1-shot          [regex] Metastatic Breast Carcinoma, Unspecified (Not Otherwise Specified)
# [ 3/50] HADM=197345 cond=counterfactual  [regex] Metastatic Breast Cancer with Complications
# [ 4/50] HADM=197345 cond=negated         [regex] Metastatic Breast Cancer
# [ 5/50] HADM=197345 cond=random_masked   [regex] Metastatic Breast Cancer
# [ 6/50] HADM=176830 cond=0-shot          [regex] Gastrointestinal Bleed
# [ 7/50] HADM=176830 cond=1-shot          [regex] Gastrointestinal Bleed
# [ 8/50] HADM=176830 cond=counterfactual  [regex] Gastrointestinal Bleed
# [ 9/50] HADM=176830 cond=negated         [regex] Gastrointestinal Bleed
# [10/50] HADM=176830 cond=random_masked   [regex] Recurrent Gastrointestinal Bleeding
# [11/50] HADM=146302 cond=0-shot          [regex] Large Subcapsular Splenic Hematoma
# [12/50] HADM=146302 cond=1-shot          [regex] splenic hematoma and ascites
# [13/50] HADM=146302 cond=counterfactual  [regex] Subcapsular Splenic Hematoma and Ascites Secondary to Ventriculoperitoneal Shunt
# [14/50] HADM=146302 cond=negated         [regex] Large Subcapsular Splenic Hematoma
# [15/50] HADM=146302 cond=random_masked   [regex] Acute Intraperitoneal Hemorrhage Due to Splenic Hematoma
# [16/50] HADM=101908 cond=0-shot          [regex] Renal Cell Carcinoma
# [17/50] HADM=101908 cond=1-shot          [regex] Renal Cell Carcinoma
# [18/50] HADM=101908 cond=counterfactual  [regex] Post-obstructive pneumonia with right lower lobe collapse
# [19/50] HADM=101908 cond=negated         [regex] Renal Cell Carcinoma
# [20/50] HADM=101908 cond=random_masked   [regex] Renal Cell Carcinoma
# [21/50] HADM=181521 cond=0-shot          [regex] Coronary Artery Disease
# [22/50] HADM=181521 cond=1-shot          [regex] Coronary Artery Disease
# [23/50] HADM=181521 cond=counterfactual  [regex] Acute Kidney Injury Secondary to Heart Failure
# [24/50] HADM=181521 cond=negated         [regex] Coronary Artery Disease
# [25/50] HADM=181521 cond=random_masked   [regex] Coronary Artery Disease
# [26/50] HADM=194302 cond=0-shot          [regex] Small Bowel Obstruction Secondary to Parastomal Hernia
# [27/50] HADM=194302 cond=1-shot          [regex] Malnutrition
# [28/50] HADM=194302 cond=counterfactual  [regex] Small Bowel Obstruction Secondary to Parastomal Hernia
# [29/50] HADM=194302 cond=negated         [regex] Small Bowel Obstruction Secondary to Parastomal Hernia
# [30/50] HADM=194302 cond=random_masked   [regex] Small Bowel Obstruction Secondary to Parastomal Hernia
# [31/50] HADM=130788 cond=0-shot          [regex] tracheomalacia
# [32/50] HADM=130788 cond=1-shot          [regex] tracheomalacia
# [33/50] HADM=130788 cond=counterfactual  [llm] Tracheomalacia
# [34/50] HADM=130788 cond=negated         [regex] tracheomalacia
# [35/50] HADM=130788 cond=random_masked   [regex] Chronic Bronchitis
# [36/50] HADM=186753 cond=0-shot          [regex] Heart Failure
# [37/50] HADM=186753 cond=1-shot          [regex] Heart Failure, Unspecified, Acute or Chronic
# [38/50] HADM=186753 cond=counterfactual  [regex] Acute Coronary Syndrome (Unstable Angina)
# [39/50] HADM=186753 cond=negated         [regex] Heart Failure
# [40/50] HADM=186753 cond=random_masked   [regex] Acute Coronary Syndrome Secondary to Chronic Coronary Artery Disease
# [41/50] HADM=166328 cond=0-shot          [regex] Dysphagia
# [42/50] HADM=166328 cond=1-shot          [regex] Malnutrition (protein-energy, unspecified)
# [43/50] HADM=166328 cond=counterfactual  [regex] Acute Kidney Injury Secondary to Septic Shock
# [44/50] HADM=166328 cond=negated         [regex] Dysphagia
# [45/50] HADM=166328 cond=random_masked   [regex] Nutritional Support Required
# [46/50] HADM=128089 cond=0-shot          [regex] Urosepsis
# [47/50] HADM=128089 cond=1-shot          [regex] Urosepsis
# [48/50] HADM=128089 cond=counterfactual  [regex] Urosepsis
# [49/50] HADM=128089 cond=negated         [regex] Urosepsis
# [50/50] HADM=128089 cond=random_masked   [regex] Urosepsis
#
# Done -> C:\Users\USER\Downloads\llama_dsk_8b_results_with_pd.csv
#   regex extracted : 49/50
#   llm  extracted  : 1/50
#   errors          : 0
#
#  HADM_ID      condition                                                                     predicted_pd pd_method
#   197345         0-shot                                                         Metastatic Breast Cancer     regex
#   197345         1-shot               Metastatic Breast Carcinoma, Unspecified (Not Otherwise Specified)     regex
#   197345 counterfactual                                      Metastatic Breast Cancer with Complications     regex
#   197345        negated                                                         Metastatic Breast Cancer     regex
#   197345  random_masked                                                         Metastatic Breast Cancer     regex
#   176830         0-shot                                                           Gastrointestinal Bleed     regex
#   176830         1-shot                                                           Gastrointestinal Bleed     regex
#   176830 counterfactual                                                           Gastrointestinal Bleed     regex
#   176830        negated                                                           Gastrointestinal Bleed     regex
#   176830  random_masked                                              Recurrent Gastrointestinal Bleeding     regex
#   146302         0-shot                                               Large Subcapsular Splenic Hematoma     regex
#   146302         1-shot                                                     splenic hematoma and ascites     regex
#   146302 counterfactual Subcapsular Splenic Hematoma and Ascites Secondary to Ventriculoperitoneal Shunt     regex
#   146302        negated                                               Large Subcapsular Splenic Hematoma     regex
#   146302  random_masked                         Acute Intraperitoneal Hemorrhage Due to Splenic Hematoma     regex
#   101908         0-shot                                                             Renal Cell Carcinoma     regex
#   101908         1-shot                                                             Renal Cell Carcinoma     regex
#   101908 counterfactual                        Post-obstructive pneumonia with right lower lobe collapse     regex
#   101908        negated                                                             Renal Cell Carcinoma     regex
#   101908  random_masked                                                             Renal Cell Carcinoma     regex
#   181521         0-shot                                                          Coronary Artery Disease     regex
#   181521         1-shot                                                          Coronary Artery Disease     regex
#   181521 counterfactual                                   Acute Kidney Injury Secondary to Heart Failure     regex
#   181521        negated                                                          Coronary Artery Disease     regex
#   181521  random_masked                                                          Coronary Artery Disease     regex
#   194302         0-shot                           Small Bowel Obstruction Secondary to Parastomal Hernia     regex
#   194302         1-shot                                                                     Malnutrition     regex
#   194302 counterfactual                           Small Bowel Obstruction Secondary to Parastomal Hernia     regex
#   194302        negated                           Small Bowel Obstruction Secondary to Parastomal Hernia     regex
#   194302  random_masked                           Small Bowel Obstruction Secondary to Parastomal Hernia     regex
#   130788         0-shot                                                                   tracheomalacia     regex
#   130788         1-shot                                                                   tracheomalacia     regex
#   130788 counterfactual                                                                   Tracheomalacia       llm
#   130788        negated                                                                   tracheomalacia     regex
#   130788  random_masked                                                               Chronic Bronchitis     regex
#   186753         0-shot                                                                    Heart Failure     regex
#   186753         1-shot                                     Heart Failure, Unspecified, Acute or Chronic     regex
#   186753 counterfactual                                        Acute Coronary Syndrome (Unstable Angina)     regex
#   186753        negated                                                                    Heart Failure     regex
#   186753  random_masked             Acute Coronary Syndrome Secondary to Chronic Coronary Artery Disease     regex
#   166328         0-shot                                                                        Dysphagia     regex
#   166328         1-shot                                       Malnutrition (protein-energy, unspecified)     regex
#   166328 counterfactual                                    Acute Kidney Injury Secondary to Septic Shock     regex
#   166328        negated                                                                        Dysphagia     regex
#   166328  random_masked                                                     Nutritional Support Required     regex
#   128089         0-shot                                                                        Urosepsis     regex
#   128089         1-shot                                                                        Urosepsis     regex
#   128089 counterfactual                                                                        Urosepsis     regex
#   128089        negated                                                                        Urosepsis     regex
#   128089  random_masked                                                                        Urosepsis     regex
