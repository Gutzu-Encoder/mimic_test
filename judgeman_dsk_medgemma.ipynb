# %%
import json
import re
import time
import os
import pandas as pd
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
API_KEY = os.getenv("DEEPSEEK_API_KEY")

INPUT_FILE   = r"C:\Users\USER\Downloads\medgemma_results_with_pd.csv"
MIMIC_FIXED  = r"C:\Users\USER\Downloads\augmented_data_mimic_fixed.csv"
OUTPUT_0SHOT = r"C:\Users\USER\Downloads\medgemma_judgedsk_0shot.csv"
OUTPUT_1SHOT = r"C:\Users\USER\Downloads\medgemma_judgedsk_1shot.csv"
MODEL = "deepseek-v4-pro"

client = OpenAI(
    api_key=API_KEY,
    base_url="https://api.deepseek.com"
)

SYSTEM_PROMPT = """You are a clinical diagnostic auditor.
Evaluate the accuracy of the Model's extracted diagnosis against the Ground Truth.
Score D1 DIAGNOSIS ACCURACY (0-3).

3: Correct match (exact or clinically equivalent synonym).
2: Correct organ system/category, but wrong specificity.
1: Correct diagnosis appears only in differential/minor mention.
0: Incorrect or missing entirely.

Return ONLY JSON:
{
  "d1_accuracy": <0-3>,
  "model_dx": "<extracted model diagnosis>",
  "reasoning": "<one sentence explanation>"
}"""

def judge_accuracy(row):
    prompt = f"Model Diagnosis: {row['predicted_pd']}\nGround Truth: {row['LONG_TITLE']}"
    try:
        response = client.chat.completions.create(
            model=MODEL,
            messages=[
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user", "content": prompt}
            ],
            extra_body={"thinking": {"type": "enabled"}},
            max_tokens=3072,
            temperature=0.0
        )
        content = response.choices[0].message.content
        if not content or not content.strip():
            raise ValueError("Empty response from API")
        clean_content = re.sub(r"```json|```", "", content).strip()
        return json.loads(clean_content)
    except Exception as e:
        return {
            "d1_accuracy": -1,
            "model_dx": "",
            "reasoning": str(e)
        }

# %%
df = pd.read_csv(INPUT_FILE)

# Replace wrong ground truths — neweraugmented_mimic.csv had incorrect ICD codes for most HADMs
mimic_fixed = (
    pd.read_csv(MIMIC_FIXED)[['HADM_ID', 'ground_truth', 'SHORT_TITLE', 'LONG_TITLE']]
    .drop_duplicates('HADM_ID')
)
df = df.drop(columns=[c for c in ['ground_truth', 'SHORT_TITLE', 'LONG_TITLE'] if c in df.columns])
df = df.merge(mimic_fixed, on='HADM_ID', how='left')

print(f"Loaded {len(df)} rows | ground truth source: augmented_data_mimic_fixed.csv")
print(df[['HADM_ID', 'LONG_TITLE']].drop_duplicates('HADM_ID').to_string(index=False))

df_baseline = (
    df[df['condition'].isin(['0-shot', '1-shot'])]
    .drop_duplicates(subset=['HADM_ID', 'condition'], keep='first')
    .copy()
)

n_0shot = (df_baseline['condition'] == '0-shot').sum()
n_1shot = (df_baseline['condition'] == '1-shot').sum()
print(f"\nProcessing {len(df_baseline)} baseline rows: {n_0shot} x 0-shot, {n_1shot} x 1-shot")

results = []
for i, (_, row) in enumerate(df_baseline.iterrows()):
    condition = row['condition']
    print(f"[{i+1}/{len(df_baseline)}] [{condition}] HADM {row['HADM_ID']}...")

    evaluation = judge_accuracy(row)
    print(evaluation)

    combined = {**row.to_dict(), **evaluation}
    results.append(combined)

    time.sleep(0.5)

results_df = pd.DataFrame(results)

df_0shot = results_df[results_df['condition'] == '0-shot']
df_1shot = results_df[results_df['condition'] == '1-shot']

df_0shot.to_csv(OUTPUT_0SHOT, index=False)
df_1shot.to_csv(OUTPUT_1SHOT, index=False)

print(f"\n--- Results ---")
print(f"0-shot  ({len(df_0shot)} rows) → {OUTPUT_0SHOT}  |  avg d1: {df_0shot['d1_accuracy'].mean():.2f}")
print(f"1-shot  ({len(df_1shot)} rows) → {OUTPUT_1SHOT}  |  avg d1: {df_1shot['d1_accuracy'].mean():.2f}")
# Out:
# Loaded 50 rows | ground truth source: augmented_data_mimic_fixed.csv
#  HADM_ID                                                       LONG_TITLE
#   197345   Secondary malignant neoplasm of retroperitoneum and peritoneum
#   176830                Hemorrhage of gastrointestinal tract, unspecified
#   146302                                         Other diseases of spleen
#   101908          Other pulmonary insufficiency, not elsewhere classified
#   181521                            Congestive heart failure, unspecified
#   194302                     Other colostomy and enterostomy complication
#   130788 Other diseases of trachea and bronchus, not elsewhere classified
#   186753               Coronary atherosclerosis of native coronary artery
#   166328                                    Other postoperative infection
#   128089                                           Unspecified septicemia
#
# Processing 20 baseline rows: 10 x 0-shot, 10 x 1-shot
# [1/20] [0-shot] HADM 197345...
# {'d1_accuracy': 0, 'model_dx': 'Metastatic Breast Cancer', 'reasoning': 'The model diagnosis specifies a primary breast cancer with metastasis, while the ground truth is a secondary malignant neoplasm of the retroperitoneum and peritoneum without mention of breast origin, making them entirely different diagnoses.'}
# [2/20] [1-shot] HADM 197345...
# {'d1_accuracy': 2, 'model_dx': 'metastatic breast cancer with peritoneal carcinomatosis and malignant pleural effusion', 'reasoning': 'Model correctly identifies peritoneal carcinomatosis (secondary neoplasm of peritoneum) but fails to mention retroperitoneal involvement specified in ground truth, resulting in partial specificity.'}
# [3/20] [0-shot] HADM 176830...
# {'d1_accuracy': 3, 'model_dx': 'Gastrointestinal bleed', 'reasoning': 'The model\'s diagnosis "Gastrointestinal bleed" is clinically synonymous with the ground truth "Hemorrhage of gastrointestinal tract, unspecified", so it is an exact match.'}
# [4/20] [1-shot] HADM 176830...
# {'d1_accuracy': 3, 'model_dx': 'Recurrent Gastrointestinal Bleed', 'reasoning': "The model's diagnosis of recurrent gastrointestinal bleed is clinically equivalent to the ground truth's hemorrhage of gastrointestinal tract, unspecified."}
# [5/20] [0-shot] HADM 146302...
# {'d1_accuracy': 2, 'model_dx': 'Large Subcapsular Splenic Hematoma', 'reasoning': "The model diagnosis is a specific splenic condition that falls under the broader ground truth category 'Other diseases of spleen', making it correct in organ system but lacking the required generality."}
# [6/20] [1-shot] HADM 146302...
# {'d1_accuracy': 2, 'model_dx': 'Splenic Hematoma', 'reasoning': "The model diagnosis is a specific spleen condition, which falls under the broader ground truth category 'Other diseases of spleen', so organ system is correct but specificity is wrong."}
# [7/20] [0-shot] HADM 101908...
# {'d1_accuracy': 0, 'model_dx': 'Renal cell carcinoma', 'reasoning': 'Model diagnosis is a kidney cancer, while ground truth is a pulmonary condition—no overlap in organ system or category.'}
# [8/20] [1-shot] HADM 101908...
# {'d1_accuracy': 0, 'model_dx': 'Post-obstructive pneumonia', 'reasoning': 'Model diagnosis is a specific infectious/inflammatory condition, while ground truth is a functional insufficiency category; they are clinically distinct and not equivalent, so the diagnosis is incorrect.'}
# [9/20] [0-shot] HADM 181521...
# {'d1_accuracy': 2, 'model_dx': 'Acute Coronary Syndrome (ACS)', 'reasoning': 'Both are cardiovascular conditions, but Acute Coronary Syndrome (ACS) and congestive heart failure are distinct diagnoses with differing pathophysiology, making this a correct organ system match with incorrect specificity.'}
# [10/20] [1-shot] HADM 181521...
# {'d1_accuracy': 0, 'model_dx': 'Acute Coronary Syndrome (ACS)', 'reasoning': 'The model diagnosis of acute coronary syndrome is a distinct condition from congestive heart failure; no match or correct organ system specificity.'}
# [11/20] [0-shot] HADM 194302...
# {'d1_accuracy': 2, 'model_dx': 'Small Bowel Obstruction', 'reasoning': 'The model diagnosis is a specific gastrointestinal condition that can be a complication of an enterostomy, but the ground truth is a broader category requiring the stoma context, so it is correct in organ system but lacks specificity.'}
# [12/20] [1-shot] HADM 194302...
# {'d1_accuracy': 2, 'model_dx': 'Small Bowel Obstruction', 'reasoning': 'The model diagnosis is a specific gastrointestinal condition that may fall under the broader category of colostomy/enterostomy complications, indicating correct organ system but insufficient specificity to match the exact category.'}
# [13/20] [0-shot] HADM 130788...
# {'d1_accuracy': 2, 'model_dx': 'Subglottic Stenosis', 'reasoning': "Subglottic stenosis is a specific disease of the trachea, falling under the broader category of 'Other diseases of trachea and bronchus,' so the organ system is correct but the specificity differs."}
# [14/20] [1-shot] HADM 130788...
# {'d1_accuracy': 2, 'model_dx': 'Tracheomalacia', 'reasoning': 'The model extracted a specific tracheal disease (tracheomalacia), which is a subset of the broader ground truth category, so the organ system is correct but specificity differs.'}
# [15/20] [0-shot] HADM 186753...
# {'d1_accuracy': 2, 'model_dx': 'Acute Coronary Syndrome (ACS)', 'reasoning': 'Model correctly identifies a coronary artery disease category but with wrong specificity, as ground truth is the underlying atherosclerosis rather than the acute syndrome.'}
# [16/20] [1-shot] HADM 186753...
# {'d1_accuracy': 2, 'model_dx': 'Acute Coronary Syndrome (ACS)', 'reasoning': 'The model identified a related acute manifestation of coronary atherosclerosis, but the ground truth specifies the underlying chronic pathological diagnosis, thus correct organ system with wrong specificity.'}
# [17/20] [0-shot] HADM 166328...
# {'d1_accuracy': 0, 'model_dx': 'Malnutrition with Enteral Nutrition', 'reasoning': "The model diagnosis 'Malnutrition with Enteral Nutrition' is entirely unrelated to the ground truth 'Other postoperative infection'; no clinical equivalence or category overlap."}
# [18/20] [1-shot] HADM 166328...
# {'d1_accuracy': 0, 'model_dx': 'Malnutrition (protein-energy, unspecified)', 'reasoning': 'Model diagnosis is malnutrition, while ground truth is postoperative infection; completely unrelated.'}
# [19/20] [0-shot] HADM 128089...
# {'d1_accuracy': 2, 'model_dx': 'Urosepsis', 'reasoning': 'Both are sepsis but model added urinary focus where ground truth is unspecified, thus correct category with wrong specificity.'}
# [20/20] [1-shot] HADM 128089...
# {'d1_accuracy': 2, 'model_dx': 'Urosepsis', 'reasoning': 'Urosepsis is a form of septicemia, so the category matches, but the model incorrectly specifies a urinary source when the ground truth is unspecified septicemia.'}
#
# --- Results ---
# 0-shot  (10 rows) → C:\Users\USER\Downloads\medgemma_judgedsk_0shot.csv  |  avg d1: 1.50
# 1-shot  (10 rows) → C:\Users\USER\Downloads\medgemma_judgedsk_1shot.csv  |  avg d1: 1.50
