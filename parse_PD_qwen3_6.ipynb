# %%
import os
import re
import json
import time
import pandas as pd
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()

INPUT_FILE  = r"C:\Users\USER\Downloads\qwen3_6_results_dedup.csv"
OUTPUT_FILE = r"C:\Users\USER\Downloads\qwen3_6_results_with_pd.csv"

# ── Regex patterns (tried in order; last match wins per pattern) ──────────────

# A: **[Final|Most Supported] Principal Diagnosis:** text_on_same_line
_PA = re.compile(
    r'\*\*(?:Final\s+|Most Supported\s+)?Principal Diagnosis[:\]]\*\*[:\s]*'
    r'(?!\s*\n\s*\*\*)'            # not followed by newline+bold (those hit PB)
    r'([^\n\*]{3,300})',
    re.IGNORECASE,
)

# B: **[Final|Most Supported] Principal Diagnosis:**\n**text** (text on next line in bold)
_PB = re.compile(
    r'\*\*(?:Final\s+|Most Supported\s+)?Principal Diagnosis[:\]]\*\*[:\s]*\n\s*'
    r'\*\*([^*\n]{3,300})\*\*',
    re.IGNORECASE,
)

# C: ### **Principal Diagnosis** \n **text**   (heading style)
_PC = re.compile(
    r'###\s+\*?\*?Principal Diagnosis\*?\*?\s*\n+\*?\*?([^\n\*]{3,300})',
    re.IGNORECASE,
)

# D: **Principal Diagnosis: text**  (colon + text inside bold span)
_PD = re.compile(
    r'\*\*(?:Final\s+|Most Supported\s+)?Principal Diagnosis:\s*([^*\n]{3,300})\*\*',
    re.IGNORECASE,
)

# E: **bold text** is the most [X] supported principal diagnosis
_PE = re.compile(
    r'\*\*([^*\n]{3,200})\*\*\s+is the most\s+\w*\s*supported principal diagnosis',
    re.IGNORECASE,
)

# F: "the most [X] supported principal diagnosis is **text**" or plain text
_PF = re.compile(
    r'most\s+\w*\s*supported principal diagnosis\s+is\s+\*?\*?([^.*\n]{3,200})',
    re.IGNORECASE,
)

PATTERNS = [_PB, _PC, _PA, _PD, _PE, _PF]   # PB before PA so multiline wins


def extract_with_regex(text: str):
    """Return the LAST match across all patterns, or None if no pattern fires."""
    best = None
    for pat in PATTERNS:
        matches = pat.findall(text)
        if matches:
            candidate = matches[-1].strip().rstrip('*').strip()
            # prefer later occurrence in text (proxy: longer search)
            best = candidate
            break   # stop at the first pattern that fires; patterns ordered by specificity
    return best or None


# quick self-test on a few known strings
_tests = [
    ("**Principal Diagnosis:** Urosepsis (UTI)",        "Urosepsis (UTI)"),
    ("**Most Supported Principal Diagnosis:**\n**Unstable Angina**", "Unstable Angina"),
    ("### **Principal Diagnosis**\n**Metastatic Breast Cancer**",    "Metastatic Breast Cancer"),
    ("**Principal Diagnosis: Tracheomalacia** (congenital)",         "Tracheomalacia"),
    ("**Splenic Hematoma** is the most strongly supported principal diagnosis", "Splenic Hematoma"),
    ("most supported principal diagnosis is **Small Bowel Obstruction**",       "Small Bowel Obstruction"),
]
for text, expected in _tests:
    got = extract_with_regex(text)
    status = "OK" if (got and expected.lower() in got.lower()) else f"FAIL (got: {got!r})"
    print(f"  {status} | expected: {expected!r}")
# Out:
#   OK | expected: 'Urosepsis (UTI)'
#   OK | expected: 'Unstable Angina'
#   OK | expected: 'Metastatic Breast Cancer'
#   OK | expected: 'Tracheomalacia'
#   OK | expected: 'Splenic Hematoma'
#   OK | expected: 'Small Bowel Obstruction'

# %%
API_KEY = os.getenv("DEEPSEEK_API_KEY")
MODEL   = "deepseek-v4-flash"   # fast/cheap flash variant

client = OpenAI(api_key=API_KEY, base_url="https://api.deepseek.com")

EXTRACT_SYSTEM = """You are a clinical NLP extraction assistant.
You will receive the FINAL portion of a model's clinical reasoning output.
Your only job: identify the model's stated principal diagnosis and return it as a short phrase.

Rules:
- Extract exactly what the model concludes, do not infer or add information.
- If the model explicitly names a diagnosis at the end, use that.
- If ambiguous between two candidates, pick the one stated last or most emphatically.
- Strip ICD codes, qualifiers like "(with secondary ...)", footnotes, and coding notes — keep only the core diagnosis name.
- If no clear principal diagnosis is stated, return "UNCLEAR".

Return ONLY valid JSON (no markdown fences):
{"principal_diagnosis": "<short diagnosis phrase>"}"""


def extract_with_llm(tail: str) -> str:
    try:
        resp = client.chat.completions.create(
            model=MODEL,
            messages=[
                {"role": "system", "content": EXTRACT_SYSTEM},
                {"role": "user",   "content": tail},
            ],
            max_tokens=128,
            temperature=0.0,
        )
        raw = resp.choices[0].message.content
        clean = re.sub(r"```json|```", "", raw).strip()
        return json.loads(clean)["principal_diagnosis"]
    except Exception as e:
        return f"ERROR: {e}"

# %%
df = pd.read_csv(INPUT_FILE)
print(f"Loaded {len(df)} rows from {INPUT_FILE}")

predicted_pds = []
methods       = []

for i, row in df.iterrows():
    text = str(row["final_answer"])

    pd_value = extract_with_regex(text)
    if pd_value:
        method = "regex"
    else:
        # Feed the last 1200 chars so the LLM sees the conclusion
        tail     = text[-1200:]
        pd_value = extract_with_llm(tail)
        method   = "llm"
        time.sleep(0.3)   # only sleep when hitting the API

    print(f"[{i+1:>2}/{len(df)}] HADM={row['HADM_ID']} cond={row['condition']:<15} [{method}] {pd_value[:90]}")
    predicted_pds.append(pd_value)
    methods.append(method)

df["predicted_pd"] = predicted_pds
df["pd_method"]    = methods

df.to_csv(OUTPUT_FILE, index=False)

# ── Summary ────────────────────────────────────────────────────────────────────
n_regex = methods.count("regex")
n_llm   = methods.count("llm")
n_err   = sum(1 for v in predicted_pds if str(v).startswith("ERROR"))
print(f"\nDone → {OUTPUT_FILE}")
print(f"  regex extracted : {n_regex}/{len(df)}")
print(f"  llm  extracted  : {n_llm}/{len(df)}")
print(f"  errors          : {n_err}")
print()
print(df[["HADM_ID", "condition", "ground_truth", "predicted_pd", "pd_method"]].to_string(index=False))
# Out:
# Loaded 50 rows from C:\Users\USER\Downloads\qwen3_6_results_dedup.csv
# [ 1/50] HADM=101908 cond=0-shot          [regex] Metastatic Renal Cell Carcinoma (with post-obstructive pneumonia/respiratory failure)
# [ 2/50] HADM=101908 cond=1-shot          [regex] Metastatic Renal Cell Carcinoma
# [ 3/50] HADM=101908 cond=counterfactual  [regex] Metastatic Renal Cell Carcinoma
# [ 4/50] HADM=101908 cond=negated         [regex] `Post-obstructive pneumonia secondary to malignant bronchial obstruction from metastatic r
# [ 5/50] HADM=101908 cond=random_masked   [regex] Metastatic Renal Cell Carcinoma (with post-obstructive pneumonia/respiratory failure)
# [ 6/50] HADM=128089 cond=0-shot          [regex] Urosepsis (Sepsis secondary to Urinary Tract Infection)
# [ 7/50] HADM=128089 cond=1-shot          [llm] ERROR: Unterminated string starting at: line 1 column 25 (char 24)
# [ 8/50] HADM=128089 cond=counterfactual  [regex] Urosepsis (Sepsis secondary to Urinary Tract Infection)
# [ 9/50] HADM=128089 cond=negated         [regex] Urosepsis (Sepsis secondary to Urinary Tract Infection)
# [10/50] HADM=128089 cond=random_masked   [llm] Urosepsis
# [11/50] HADM=130788 cond=0-shot          [regex] Severe Tracheobronchomalacia (ICD-10-CM: J98.2)
# [12/50] HADM=130788 cond=1-shot          [regex] Severe Tracheobronchomalacia (Dynamic Airway Collapse)
# [13/50] HADM=130788 cond=counterfactual  [llm] ERROR: Expecting value: line 1 column 1 (char 0)
# [14/50] HADM=130788 cond=negated         [regex] Severe Tracheobronchomalacia (ICD-10-CM: J98.2)
# [15/50] HADM=130788 cond=random_masked   [regex] Tracheomalacia
# [16/50] HADM=146302 cond=0-shot          [llm] splenic hematoma
# [17/50] HADM=146302 cond=1-shot          [regex] Splenic Hematoma with Intraperitoneal Hemorrhage
# [18/50] HADM=146302 cond=counterfactual  [llm] ERROR: Expecting value: line 1 column 1 (char 0)
# [19/50] HADM=146302 cond=negated         [regex] Spontaneous Splenic Subcapsular Hematoma with Intraperitoneal Hemorrhage
# [20/50] HADM=146302 cond=random_masked   [llm] ERROR: Expecting value: line 1 column 1 (char 0)
# [21/50] HADM=166328 cond=0-shot          [regex] Complicated intra-abdominal infection
# [22/50] HADM=166328 cond=1-shot          [llm] Malnutrition
# [23/50] HADM=166328 cond=counterfactual  [regex] Acute Kidney Injury (AKI) secondary to Septic Shock (from wound infection)
# [24/50] HADM=166328 cond=negated         [regex] Complicated intra-abdominal infection
# [25/50] HADM=166328 cond=random_masked   [regex] Complicated intra-abdominal infection
# [26/50] HADM=176830 cond=0-shot          [regex] Gastrointestinal Bleeding (Recurrent Lower GI Hemorrhage)
# [27/50] HADM=176830 cond=1-shot          [regex] Lower gastrointestinal hemorrhage (Gastrointestinal bleed)
# [28/50] HADM=176830 cond=counterfactual  [regex] Lower Gastrointestinal Bleed (Gastrointestinal Hemorrhage)
# [29/50] HADM=176830 cond=negated         [regex] Lower Gastrointestinal Bleed (Gastrointestinal Hemorrhage)
# [30/50] HADM=176830 cond=random_masked   [regex] Gastrointestinal Bleeding (Recurrent Lower GI Hemorrhage)
# [31/50] HADM=181521 cond=0-shot          [regex] Acute Myocardial Infarction (STEMI) / Coronary Artery Disease
# [32/50] HADM=181521 cond=1-shot          [regex] Acute ST-segment elevation myocardial infarction (STEMI)
# [33/50] HADM=181521 cond=counterfactual  [regex] Acute ST-Elevation Myocardial Infarction (STEMI) secondary to severe multivessel Coronary
# [34/50] HADM=181521 cond=negated         [regex] Acute Myocardial Infarction (specifically, Anterior/Inferoapical STEMI)
# [35/50] HADM=181521 cond=random_masked   [regex] Acute Myocardial Infarction (STEMI) / Coronary Artery Disease
# [36/50] HADM=186753 cond=0-shot          [regex] Unstable Angina (Acute Coronary Syndrome)
# [37/50] HADM=186753 cond=1-shot          [llm] ERROR: Expecting value: line 1 column 1 (char 0)
# [38/50] HADM=186753 cond=counterfactual  [llm] ERROR: Expecting value: line 1 column 1 (char 0)
# [39/50] HADM=186753 cond=negated         [regex] Unstable Angina (Acute Coronary Syndrome)
# [40/50] HADM=186753 cond=random_masked   [regex] Unstable Angina (ICD-10: I20.0)
# [41/50] HADM=194302 cond=0-shot          [regex] Small Bowel Obstruction (SBO) secondary to adhesions and parastomal hernia
# [42/50] HADM=194302 cond=1-shot          [regex] Small Bowel Obstruction (secondary to adhesions and parastomal hernia)
# [43/50] HADM=194302 cond=counterfactual  [regex] Small Bowel Obstruction
# [44/50] HADM=194302 cond=negated         [regex] Small Bowel Obstruction (SBO) secondary to adhesions and parastomal hernia
# [45/50] HADM=194302 cond=random_masked   [regex] Small Bowel Obstruction (SBO) secondary to adhesions and parastomal hernia.
# [46/50] HADM=197345 cond=0-shot          [regex] Metastatic Breast Cancer
# [47/50] HADM=197345 cond=1-shot          [regex] Metastatic Breast Cancer (Refractory, with widespread metastases)
# [48/50] HADM=197345 cond=counterfactual  [regex] Metastatic Breast Cancer
# [49/50] HADM=197345 cond=negated         [regex] Metastatic Breast Cancer
# [50/50] HADM=197345 cond=random_masked   [regex] Metastatic Breast Cancer (refractory, with malignant pleural effusion, ascites/omental car
#
# Done → C:\Users\USER\Downloads\qwen3_6_results_with_pd.csv
#   regex extracted : 41/50
#   llm  extracted  : 9/50
#   errors          : 6
#
#  HADM_ID      condition  ground_truth                                                                                                                                         predicted_pd pd_method
#   101908         0-shot         51882                                                                Metastatic Renal Cell Carcinoma (with post-obstructive pneumonia/respiratory failure)     regex
#   101908         1-shot         51882                                                                                                                      Metastatic Renal Cell Carcinoma     regex
#   101908 counterfactual         51882                                                                                                                      Metastatic Renal Cell Carcinoma     regex
#   101908        negated         51882                                       `Post-obstructive pneumonia secondary to malignant bronchial obstruction from metastatic renal cell carcinoma`     regex
#   101908  random_masked         51882                                                                Metastatic Renal Cell Carcinoma (with post-obstructive pneumonia/respiratory failure)     regex
#   128089         0-shot          5849                                                                                              Urosepsis (Sepsis secondary to Urinary Tract Infection)     regex
#   128089         1-shot          5849                                                                                   ERROR: Unterminated string starting at: line 1 column 25 (char 24)       llm
#   128089 counterfactual          5849                                                                                              Urosepsis (Sepsis secondary to Urinary Tract Infection)     regex
#   128089        negated          5849                                                                                              Urosepsis (Sepsis secondary to Urinary Tract Infection)     regex
#   128089  random_masked          5849                                                                                                                                            Urosepsis       llm
#   130788         0-shot          2594                                                                                                      Severe Tracheobronchomalacia (ICD-10-CM: J98.2)     regex
#   130788         1-shot          2594                                                                                               Severe Tracheobronchomalacia (Dynamic Airway Collapse)     regex
#   130788 counterfactual          2594                                                                                                     ERROR: Expecting value: line 1 column 1 (char 0)       llm
#   130788        negated          2594                                                                                                      Severe Tracheobronchomalacia (ICD-10-CM: J98.2)     regex
#   130788  random_masked          2594                                                                                                                                       Tracheomalacia     regex
#   146302         0-shot           412                                                                                                                                     splenic hematoma       llm
#   146302         1-shot           412                                                                                                     Splenic Hematoma with Intraperitoneal Hemorrhage     regex
#   146302 counterfactual           412                                                                                                     ERROR: Expecting value: line 1 column 1 (char 0)       llm
#   146302        negated           412                                                                             Spontaneous Splenic Subcapsular Hematoma with Intraperitoneal Hemorrhage     regex
#   146302  random_masked           412                                                                                                     ERROR: Expecting value: line 1 column 1 (char 0)       llm
#   166328         0-shot          5192                                                                                                                Complicated intra-abdominal infection     regex
#   166328         1-shot          5192                                                                                                                                         Malnutrition       llm
#   166328 counterfactual          5192                                                                           Acute Kidney Injury (AKI) secondary to Septic Shock (from wound infection)     regex
#   166328        negated          5192                                                                                                                Complicated intra-abdominal infection     regex
#   166328  random_masked          5192                                                                                                                Complicated intra-abdominal infection     regex
#   176830         0-shot          2720                                                                                            Gastrointestinal Bleeding (Recurrent Lower GI Hemorrhage)     regex
#   176830         1-shot          2720                                                                                           Lower gastrointestinal hemorrhage (Gastrointestinal bleed)     regex
#   176830 counterfactual          2720                                                                                           Lower Gastrointestinal Bleed (Gastrointestinal Hemorrhage)     regex
#   176830        negated          2720                                                                                           Lower Gastrointestinal Bleed (Gastrointestinal Hemorrhage)     regex
#   176830  random_masked          2720                                                                                            Gastrointestinal Bleeding (Recurrent Lower GI Hemorrhage)     regex
#   181521         0-shot          5939                                                                                        Acute Myocardial Infarction (STEMI) / Coronary Artery Disease     regex
#   181521         1-shot          5939                                                                                             Acute ST-segment elevation myocardial infarction (STEMI)     regex
#   181521 counterfactual          5939                                            Acute ST-Elevation Myocardial Infarction (STEMI) secondary to severe multivessel Coronary Artery Disease.     regex
#   181521        negated          5939                                                                              Acute Myocardial Infarction (specifically, Anterior/Inferoapical STEMI)     regex
#   181521  random_masked          5939                                                                                        Acute Myocardial Infarction (STEMI) / Coronary Artery Disease     regex
#   186753         0-shot         41401                                                                                                            Unstable Angina (Acute Coronary Syndrome)     regex
#   186753         1-shot         41401                                                                                                     ERROR: Expecting value: line 1 column 1 (char 0)       llm
#   186753 counterfactual         41401                                                                                                     ERROR: Expecting value: line 1 column 1 (char 0)       llm
#   186753        negated         41401                                                                                                            Unstable Angina (Acute Coronary Syndrome)     regex
#   186753  random_masked         41401                                                                                                                      Unstable Angina (ICD-10: I20.0)     regex
#   194302         0-shot          1970                                                                           Small Bowel Obstruction (SBO) secondary to adhesions and parastomal hernia     regex
#   194302         1-shot          1970                                                                               Small Bowel Obstruction (secondary to adhesions and parastomal hernia)     regex
#   194302 counterfactual          1970                                                                                                                              Small Bowel Obstruction     regex
#   194302        negated          1970                                                                           Small Bowel Obstruction (SBO) secondary to adhesions and parastomal hernia     regex
#   194302  random_masked          1970                                                                          Small Bowel Obstruction (SBO) secondary to adhesions and parastomal hernia.     regex
#   197345         0-shot          1976                                                                                                                             Metastatic Breast Cancer     regex
#   197345         1-shot          1976                                                                                    Metastatic Breast Cancer (Refractory, with widespread metastases)     regex
#   197345 counterfactual          1976                                                                                                                             Metastatic Breast Cancer     regex
#   197345        negated          1976                                                                                                                             Metastatic Breast Cancer     regex
#   197345  random_masked          1976 Metastatic Breast Cancer (refractory, with malignant pleural effusion, ascites/omental carcinomatosis, hypercalcemia, and chronic pulmonary emboli).     regex
