# %%
import json
import re
import time
import os
import pandas as pd
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
API_KEY = os.getenv("GLM_API_KEY")

INPUT_FILE   = r"C:\Users\USER\Downloads\llama_dsk_8b_results_with_pd.csv"
MIMIC_FIXED  = r"C:\Users\USER\Downloads\augmented_data_mimic_fixed.csv"
OUTPUT_0SHOT = r"C:\Users\USER\Downloads\llama8b_glmjudge_0shot.csv"
OUTPUT_1SHOT = r"C:\Users\USER\Downloads\llama8b_glmjudge_1shot.csv"
MODEL = "glm-5.1"

client = OpenAI(
    api_key=API_KEY,
    base_url="https://open.bigmodel.cn/api/paas/v4/"
)

SYSTEM_PROMPT = """You are a clinical diagnostic auditor.
Evaluate the accuracy of the Model's extracted diagnosis against the Ground Truth.
Score D1 DIAGNOSIS ACCURACY (0-3).

3: Correct match (exact or clinically equivalent synonym).
2: Correct organ system/category, but wrong specificity.
1: Correct diagnosis appears only in differential/minor mention.
0: Incorrect or missing entirely.

Return ONLY JSON:
{
  "d1_accuracy": <0-3>,
  "model_dx": "<extracted model diagnosis>",
  "reasoning": "<one sentence explanation>"
}"""

def judge_accuracy(row):
    prompt = f"Model Diagnosis: {row['predicted_pd']}\nGround Truth: {row['LONG_TITLE']}"
    try:
        response = client.chat.completions.create(
            model=MODEL,
            messages=[
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user",   "content": prompt}
            ],
            max_tokens=3072,
            temperature=0.0
        )
        content = response.choices[0].message.content
        if not content or not content.strip():
            raise ValueError("Empty response from API")
        clean_content = re.sub(r"```json|```", "", content).strip()
        return json.loads(clean_content)
    except Exception as e:
        return {
            "d1_accuracy": -1,
            "model_dx": "",
            "reasoning": str(e)
        }

# %%
df = pd.read_csv(INPUT_FILE)

# Overwrite ground truth columns with corrected principal-dx labels
mimic_fixed = pd.read_csv(MIMIC_FIXED)[['HADM_ID', 'ground_truth', 'SHORT_TITLE', 'LONG_TITLE']].drop_duplicates('HADM_ID')
df = df.drop(columns=[c for c in ['ground_truth', 'SHORT_TITLE', 'LONG_TITLE'] if c in df.columns])
df = df.merge(mimic_fixed, on='HADM_ID', how='left')

# Keep one row per (HADM_ID, condition) — removes duplicate model runs
df_baseline = (
    df[df['condition'].isin(['0-shot', '1-shot'])]
    .drop_duplicates(subset=['HADM_ID', 'condition'], keep='first')
    .copy()
)

n_0shot = (df_baseline['condition'] == '0-shot').sum()
n_1shot = (df_baseline['condition'] == '1-shot').sum()
print(f"Processing {len(df_baseline)} baseline rows: {n_0shot} x 0-shot, {n_1shot} x 1-shot")

results = []
for i, (_, row) in enumerate(df_baseline.iterrows()):
    condition = row['condition']
    print(f"[{i+1}/{len(df_baseline)}] [{condition}] HADM {row['HADM_ID']}...")

    evaluation = judge_accuracy(row)
    print(evaluation)

    combined = {**row.to_dict(), **evaluation}
    results.append(combined)

    time.sleep(0.5)

results_df = pd.DataFrame(results)

df_0shot = results_df[results_df['condition'] == '0-shot']
df_1shot = results_df[results_df['condition'] == '1-shot']

df_0shot.to_csv(OUTPUT_0SHOT, index=False)
df_1shot.to_csv(OUTPUT_1SHOT, index=False)

print(f"\n--- Results ---")
print(f"0-shot  ({len(df_0shot)} rows) → {OUTPUT_0SHOT}  |  avg d1: {df_0shot['d1_accuracy'].mean():.2f}")
print(f"1-shot  ({len(df_1shot)} rows) → {OUTPUT_1SHOT}  |  avg d1: {df_1shot['d1_accuracy'].mean():.2f}")
# Out:
# Processing 20 baseline rows: 10 x 0-shot, 10 x 1-shot
# [1/20] [0-shot] HADM 197345...
# {'d1_accuracy': 2, 'model_dx': 'Metastatic Breast Cancer', 'reasoning': 'Both fall under the general category of malignant neoplasms/metastatic disease, but the model identifies the primary site (breast) while the ground truth specifies the secondary metastatic site (retroperitoneum and peritoneum), representing a difference in specificity.'}
# [2/20] [1-shot] HADM 197345...
# {'d1_accuracy': 2, 'model_dx': 'Metastatic Breast Carcinoma, Unspecified (Not Otherwise Specified)', 'reasoning': 'Both indicate a metastatic/secondary malignant neoplasm, but the model specifies the primary site (breast) while the ground truth specifies the secondary site (retroperitoneum and peritoneum), representing a difference in specificity and focus.'}
# [3/20] [0-shot] HADM 176830...
# {'d1_accuracy': 3, 'model_dx': 'Gastrointestinal Bleed', 'reasoning': 'Gastrointestinal bleed is a clinically equivalent synonym for hemorrhage of the gastrointestinal tract, meeting the criteria for an exact match.'}
# [4/20] [1-shot] HADM 176830...
# {'d1_accuracy': 3, 'model_dx': 'Gastrointestinal Bleed', 'reasoning': 'Gastrointestinal bleed is a clinically equivalent synonym for hemorrhage of the gastrointestinal tract.'}
# [5/20] [0-shot] HADM 146302...
# {'d1_accuracy': 2, 'model_dx': 'Large Subcapsular Splenic Hematoma', 'reasoning': 'The model correctly identifies the organ system and general pathological category (spleen disease), but provides a much more specific diagnosis than the broad ground truth category.'}
# [6/20] [1-shot] HADM 146302...
# {'d1_accuracy': 2, 'model_dx': 'splenic hematoma and ascites', 'reasoning': "Splenic hematoma falls under the broad category of 'Other diseases of spleen', representing the correct organ system but differing in specificity, and ascites is an additional separate finding."}
# [7/20] [0-shot] HADM 101908...
# {'d1_accuracy': 0, 'model_dx': 'Renal Cell Carcinoma', 'reasoning': "The model's diagnosis of renal cell carcinoma is entirely incorrect and involves a completely different organ system compared to the ground truth of pulmonary insufficiency."}
# [8/20] [1-shot] HADM 101908...
# {'d1_accuracy': 0, 'model_dx': 'Renal Cell Carcinoma', 'reasoning': "The model's diagnosis of renal cell carcinoma is entirely incorrect and belongs to a different organ system compared to the ground truth of pulmonary insufficiency."}
# [9/20] [0-shot] HADM 181521...
# {'d1_accuracy': 2, 'model_dx': 'Coronary Artery Disease', 'reasoning': 'Both conditions belong to the cardiovascular organ system, but coronary artery disease and congestive heart failure are distinct diagnoses rather than variations in specificity.'}
# [10/20] [1-shot] HADM 181521...
# {'d1_accuracy': 2, 'model_dx': 'Coronary Artery Disease', 'reasoning': 'Both conditions belong to the cardiovascular organ system, but coronary artery disease and congestive heart failure are distinct diagnoses rather than variations in specificity of the same condition.'}
# [11/20] [0-shot] HADM 194302...
# {'d1_accuracy': 2, 'model_dx': 'Small Bowel Obstruction Secondary to Parastomal Hernia', 'reasoning': 'The model provides a more specific diagnosis that falls under the broader ground truth category of enterostomy complications, representing a correct organ system/category but a mismatch in specificity.'}
# [12/20] [1-shot] HADM 194302...
# {'d1_accuracy': 0, 'model_dx': 'Malnutrition', 'reasoning': 'The model diagnosis of malnutrition is entirely different from the ground truth of a colostomy and enterostomy complication, with no overlap in condition or category.'}
# [13/20] [0-shot] HADM 130788...
# {'d1_accuracy': 2, 'model_dx': 'tracheomalacia', 'reasoning': 'Tracheomalacia is a specific disease of the trachea, which correctly matches the organ system/category of the ground truth, but the ground truth is a broad, non-specific residual category rather than the specific condition.'}
# [14/20] [1-shot] HADM 130788...
# {'d1_accuracy': 2, 'model_dx': 'tracheomalacia', 'reasoning': "Tracheomalacia is a specific disease of the trachea, which correctly identifies the organ system/category of the ground truth, but it differs in specificity from the broad 'not elsewhere classified' category."}
# [15/20] [0-shot] HADM 186753...
# {'d1_accuracy': 2, 'model_dx': 'Heart Failure', 'reasoning': 'Both conditions belong to the cardiovascular system, but heart failure is a distinct clinical syndrome rather than a less specific version of coronary atherosclerosis.'}
# [16/20] [1-shot] HADM 186753...
# {'d1_accuracy': 2, 'model_dx': 'Heart Failure, Unspecified, Acute or Chronic', 'reasoning': 'Both conditions belong to the cardiovascular organ system, but heart failure and coronary atherosclerosis are distinct diagnoses rather than equivalent or differing only in specificity.'}
# [17/20] [0-shot] HADM 166328...
# {'d1_accuracy': 0, 'model_dx': 'Dysphagia', 'reasoning': 'The model diagnosis of dysphagia is entirely incorrect and shares no overlap with the ground truth of other postoperative infection.'}
# [18/20] [1-shot] HADM 166328...
# {'d1_accuracy': 0, 'model_dx': 'Malnutrition (protein-energy, unspecified)', 'reasoning': "The model's diagnosis of malnutrition is entirely incorrect and belongs to a different organ system/category than the ground truth of postoperative infection."}
# [19/20] [0-shot] HADM 128089...
# {'d1_accuracy': 2, 'model_dx': 'Urosepsis', 'reasoning': 'Urosepsis and unspecified septicemia both fall under the systemic category of sepsis, but urosepsis specifies a urinary tract origin whereas the ground truth is unspecified, representing a difference in specificity.'}
# [20/20] [1-shot] HADM 128089...
# {'d1_accuracy': 2, 'model_dx': 'Urosepsis', 'reasoning': 'Urosepsis is a specific type of septicemia, matching the correct general category of sepsis but differing in specificity from the unspecified ground truth.'}
#
# --- Results ---
# 0-shot  (10 rows) → C:\Users\USER\Downloads\llama8b_glmjudge_0shot.csv  |  avg d1: 1.70
# 1-shot  (10 rows) → C:\Users\USER\Downloads\llama8b_glmjudge_1shot.csv  |  avg d1: 1.50
